# %%
import pandas as pd

# %%
pd.read_excel('NBAModel.xlsx')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\AAGBEB~1.TSI\AppData\Local\Temp/ipykernel_17416/1491458593.py in <module>
# ----> 1 pd.read_excel('NBAModel.xlsx')
#
# NameError: name 'pd' is not defined
